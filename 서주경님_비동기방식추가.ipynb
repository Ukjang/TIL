# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
chrome_path = r'C:\pydata\chromedriver.exe'
driver = webdriver.Chrome(chrome_path)
url = 'https://sports.news.naver.com/kbaseball/record/index?category=kbo&year=2022&type=pitcher&playerOrder=era'
driver.get(url)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22116\3597611143.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path)

# %%
html = driver.page_source
soup = bs(html, 'html.parser')
soup
# Out:
# <html data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36" lang="ko"><head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=1080px,maximum-scale=2.0,minimum-scale=0.4,user-scalable=yes" name="viewport"/>
# <meta content="https://imgsports.pstatic.net/images/mobile/common/NAVERsports.png" property="og:image"/>
# <meta content="네이버 스포츠" property="og:title"/>
# <meta content="스포츠의 시작과 끝!" property="og:description"/>
# <meta content="sports.news.naver.com/kbaseball/record/index?category=kbo&amp;year=2022&amp;tab=team" property="og:url"/>
# <link href="https://ssl.pstatic.net/static.sports/resources/pc/2022/08/25/100527/css/common_loose_new.css" rel="stylesheet" type="text/css"/>
# ...

# %%
soup.select_one('#_pitcherRecord').select('span')
# Out:
# [<span>다음기록</span>,
#  <span>이전기록</span>,
#  <span class="blind">순위</span>,
#  <span class="blind">선수</span>,
#  <span class="blind">평균자책점</span>,
#  <span class="blind">경기수</span>,
#  <span class="blind">이닝</span>,
#  <span class="blind">승</span>,
#  <span class="blind">패</span>,
#  <span class="blind">세이브</span>,
#  <span class="blind">홀드</span>,
#  <span class="blind">삼진</span>,
#  <span class="blind">피안타</span>,
#  <span class="blind">피홈런</span>,
#  <span class="blind">실점</span>,
#  <span class="blind">볼넷</span>,
#  <span class="blind">사구</span>,
#  <span class="blind">승률</span>,
#  <span class="emblem"><img alt="구단 로고" height="25" onerror="imageOnError(this);" src="https://dthumb-phinf.pstatic.net/?src=https://sports-phinf.pstatic.net/team/kbo/default/SK.png&amp;type=f25_25&amp;refresh=1" width="25"/></span>,
#  <span>김광현 <span class="team">(SSG)</span></span>,
#  <span class="team">(SSG)</span>,
#  <span>24</span>,
#  <span>148 1/3</span>,
#  <span>12</span>,
# ...

# %%
soup.select_one('#_batterRecord').select('span')
# Out:
# [<span>다음기록</span>,
#  <span>이전기록</span>,
#  <span class="blind">순위</span>,
#  <span class="blind">선수</span>,
#  <span class="blind">타율</span>,
#  <span class="blind">경기수</span>,
#  <span class="blind">타수</span>,
#  <span class="blind">안타</span>,
#  <span class="blind">2루타</span>,
#  <span class="blind">3루타</span>,
#  <span class="blind">홈런</span>,
#  <span class="blind">타점</span>,
#  <span class="blind">득점</span>,
#  <span class="blind">도루</span>,
#  <span class="blind">볼넷</span>,
#  <span class="blind">삼진</span>,
#  <span class="blind">출루율</span>,
#  <span class="blind">장타율</span>,
#  <span class="blind">순위</span>,
#  <span class="blind">선수</span>,
#  <span class="blind">OPS</span>,
#  <span class="blind">IsoP</span>,
#  <span class="blind">BABIP</span>,
#  <span class="blind">wOBA</span>,
#  <span class="blind">wRC+</span>,
#  <span class="blind">WPA</span>,
#  <span class="blind">WAR</span>,
#  <span class="bl"></span>,
#  <span class="bt"></span>,
#  <span class="br"></span>,
# ...

# %%
_batterRecord

# %%
driver.find_element_by_css_selector('#_playerTypeList > li:nth-child(2) > a > span').click()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22116\279132973.py:1: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver.find_element_by_css_selector('#_playerTypeList > li:nth-child(2) > a > span').click()

# %%
html = driver.page_source
soup = bs(html, 'html.parser')
soup
# Out:
# <html data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36" lang="ko"><head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=1080px,maximum-scale=2.0,minimum-scale=0.4,user-scalable=yes" name="viewport"/>
# <meta content="https://imgsports.pstatic.net/images/mobile/common/NAVERsports.png" property="og:image"/>
# <meta content="네이버 스포츠" property="og:title"/>
# <meta content="스포츠의 시작과 끝!" property="og:description"/>
# <meta content="sports.news.naver.com/kbaseball/record/index?category=kbo&amp;year=2022&amp;tab=team" property="og:url"/>
# <link href="https://ssl.pstatic.net/static.sports/resources/pc/2022/08/25/100527/css/common_loose_new.css" rel="stylesheet" type="text/css"/>
# ...

# %%
soup.select_one('#_batterRecord').select('span')
# Out:
# [<span>다음기록</span>,
#  <span>이전기록</span>,
#  <span class="blind">순위</span>,
#  <span class="blind">선수</span>,
#  <span class="blind">타율</span>,
#  <span class="blind">경기수</span>,
#  <span class="blind">타수</span>,
#  <span class="blind">안타</span>,
#  <span class="blind">2루타</span>,
#  <span class="blind">3루타</span>,
#  <span class="blind">홈런</span>,
#  <span class="blind">타점</span>,
#  <span class="blind">득점</span>,
#  <span class="blind">도루</span>,
#  <span class="blind">볼넷</span>,
#  <span class="blind">삼진</span>,
#  <span class="blind">출루율</span>,
#  <span class="blind">장타율</span>,
#  <span class="emblem"><img alt="구단 로고" height="25" onerror="imageOnError(this);" src="https://dthumb-phinf.pstatic.net/?src=https://sports-phinf.pstatic.net/team/kbo/default/SS.png&amp;type=f25_25&amp;refresh=1" width="25"/></span>,
#  <span>피렐라 <span class="team">(삼성)</span></span>,
#  <span class="team">(삼성)</span>,
#  <span>123</span>,
#  <span>483</span>,
#  <span>166</span>,
#  <span>25</span>,
# ...

# %%
import requests
from bs4 import BeautifulSoup as bs
url = 'https://sports.news.naver.com/kbaseball/record/ajaxHtmlPlayerRecord.nhn?category=kbo&year=2022&type=batter&playerOrder=hra'
html = requests.get(url)
soup = bs(html.text, 'html.parser')
soup
# Out:
# [{"bb":51,"wrc_plus":"162.5","pcode":"51463","hr":25,"run":88,"h2":25,"h3":4,"sb":14,"hit":166,"hra":"0.344","rank":1,"gd":14,"kk":67,"woba":"0.433","ab":483,"teamCode":"SS","wpa":"2.35","war":"6.36","team":"삼성","slg":"0.567","game_count":123,"ops":"0.985","name":"피렐라","rbi":97,"babip":"0.359","isop":"0.223","obp":"0.418"},{"bb":36,"wrc_plus":"144.6","pcode":"71564","hr":20,"run":49,"h2":21,"h3":0,"sb":0,"hit":164,"hra":"0.340","rank":2,"gd":19,"kk":49,"woba":"0.395","ab":482,"teamCode":"LT","wpa":"-0.04","war":"4.67","team":"롯데","slg":"0.508","game_count":127,"ops":"0.893","name":"이대호","rbi":87,"babip":"0.345","isop":"0.168","obp":"0.385"},{"bb":60,"wrc_plus":"164.3","pcode":"67341","hr":21,"run":72,"h2":29,"h3":9,"sb":3,"hit":167,"hra":"0.340","rank":3,"gd":9,"kk":28,"woba":"0.421","ab":491,"teamCode":"WO","wpa":"3.52","war":"7.30","team":"키움","slg":"0.564","game_count":128,"ops":"0.979","name":"이정후","rbi":98,"babip":"0.328","isop":"0.224","obp":"0.415"},{"bb":32,"wrc_plus":"148.5"
# ...

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
import json
json1 = json.loads(soup.text)
json1
# Out:
# [{'bb': 51,
#   'wrc_plus': '162.5',
#   'pcode': '51463',
#   'hr': 25,
#   'run': 88,
#   'h2': 25,
#   'h3': 4,
#   'sb': 14,
#   'hit': 166,
#   'hra': '0.344',
#   'rank': 1,
#   'gd': 14,
#   'kk': 67,
#   'woba': '0.433',
#   'ab': 483,
#   'teamCode': 'SS',
#   'wpa': '2.35',
#   'war': '6.36',
#   'team': '삼성',
#   'slg': '0.567',
#   'game_count': 123,
#   'ops': '0.985',
#   'name': '피렐라',
#   'rbi': 97,
#   'babip': '0.359',
#   'isop': '0.223',
#   'obp': '0.418'},
#  {'bb': 36,
#   'wrc_plus': '144.6',
#   'pcode': '71564',
#   'hr': 20,
#   'run': 49,
#   'h2': 21,
#   'h3': 0,
#   'sb': 0,
#   'hit': 164,
#   'hra': '0.340',
#   'rank': 2,
#   'gd': 19,
#   'kk': 49,
#   'woba': '0.395',
#   'ab': 482,
#   'teamCode': 'LT',
#   'wpa': '-0.04',
#   'war': '4.67',
#   'team': '롯데',
#   'slg': '0.508',
#   'game_count': 127,
#   'ops': '0.893',
#   'name': '이대호',
#   'rbi': 87,
#   'babip': '0.345',
#   'isop': '0.168',
#   'obp': '0.385'},
#  {'bb': 60,
# ...

# %%
json1[1]
# Out:
# {'bb': 36,
#  'wrc_plus': '144.6',
#  'pcode': '71564',
#  'hr': 20,
#  'run': 49,
#  'h2': 21,
#  'h3': 0,
#  'sb': 0,
#  'hit': 164,
#  'hra': '0.340',
#  'rank': 2,
#  'gd': 19,
#  'kk': 49,
#  'woba': '0.395',
#  'ab': 482,
#  'teamCode': 'LT',
#  'wpa': '-0.04',
#  'war': '4.67',
#  'team': '롯데',
#  'slg': '0.508',
#  'game_count': 127,
#  'ops': '0.893',
#  'name': '이대호',
#  'rbi': 87,
#  'babip': '0.345',
#  'isop': '0.168',
#  'obp': '0.385'}

# %%
# 투수
url = 'https://sports.news.naver.com/kbaseball/record/ajaxHtmlPlayerRecord.nhn?category=kbo&year=2022&type=pitcher&playerOrder=hra'
html = requests.get(url)
soup = bs(html.text, 'html.parser')
json2 = json.loads(soup.text)
json2[0]
# Out:
# {'bb': 38,
#  'pa_kk_rt': '22.3',
#  'pcode': '77829',
#  'kk_bb_rt': '3.50',
#  'hp': 5,
#  'hr': 8,
#  'hold': 0,
#  'whip': '1.08',
#  'hit': 122,
#  'innk': '8.07',
#  'era': '1.94',
#  'inn2': 445,
#  'rank': 1,
#  'kk': 133,
#  'sv': 0,
#  'winp': '0.857',
#  'inn': '148 1/3',
#  'innb': '2.31',
#  'teamCode': 'SK',
#  'war': '5.14',
#  'wpa': '4.85',
#  'team': 'SSG',
#  'l': 2,
#  'game_count': 24,
#  'r': 39,
#  'w': 12,
#  'name': '김광현',
#  'pa_bb_rt': '6.4'}

# %%
json2[0]['name']
# Out:
# '김광현'
