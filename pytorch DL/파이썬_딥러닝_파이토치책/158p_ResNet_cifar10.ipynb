# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 

import torch 
import torch.nn as nn 
import torch.nn.functional as F 
from torchvision import datasets, transforms

# %%
if torch.cuda.is_available() :
    DEVICE = torch.device('cuda')
else :
    DEVICE = torch.device('cpu')
print(DEVICE, torch.cuda.get_device_name(), '\ttorch_version : {}'.format(torch.__version__))
# Out:
# cuda NVIDIA GeForce GTX 1650 	torch_version : 1.12.0

# %%
BATCH_SIZE = 128
EPOCHS = 100

# %%
train_dataset = datasets.CIFAR10(root='../../data/cifar10',
                                 download=True,
                                 train = True,
                                 transform= transforms.Compose([
                                    transforms.RandomHorizontalFlip(),
                                    transforms.ToTensor(),
                                    transforms.Normalize((0.5, 0.5, 0.5),
                                                         (0.5, 0.5, 0.5))
                                 ]))
test_dataset = datasets.CIFAR10(root='../../data/cifar10',
                                 download=True,
                                 train = False,
                                 transform= transforms.Compose([
                                    transforms.RandomHorizontalFlip(),
                                    transforms.ToTensor(),
                                    transforms.Normalize((0.5, 0.5, 0.5),
                                                         (0.5, 0.5, 0.5))
                                 ]))
train_loader = torch.utils.data.DataLoader(train_dataset,
                                           shuffle = True,
                                           batch_size = BATCH_SIZE)
test_loader = torch.utils.data.DataLoader(test_dataset,
                                           shuffle = False,
                                           batch_size = BATCH_SIZE)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
for (X_train, y_train) in train_loader :
    print(X_train.size(), y_train.size())
    print(X_train.type(), y_train.type())
    break
# Out:
# torch.Size([128, 3, 32, 32]) torch.Size([128])
# torch.FloatTensor torch.LongTensor

# %%
pltsize = 1 
plt.figure(figsize=(pltsize * 10, pltsize))
for i in range(10) :
    plt.subplot(1, 10, i + 1)
    plt.axis('off')
    plt.imshow(np.transpose(X_train[i], (1, 2, 0)))
    plt.title('Clalss :' + str(y_train[i].item()))
plt.show()

# 오류는 noramlize 되어 있어서 그럼
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class BasicBlock(nn.Module) :
    def __init__(self, in_planes, planes, stride=1) :
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes,
                               kernel_size=3,
                               stride= stride,
                               padding = 1,
                               bias = False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes,
                                kernel_size=3,
                                stride=1,
                                padding=1,
                                bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes :
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes,
                          kernel_size=1,
                          stride= stride,
                          bias=False),
                nn.BatchNorm2d(planes)
            )
    
    def forward(self, x) :
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class ResNet(nn.Module) :
    def __init__(self, num_classes=10) :
        super(ResNet, self).__init__()
        self.in_planes = 16
        self.conv1 = nn.Conv2d(3, 16,
                               kernel_size=3,
                               stride=1,
                               padding=1,
                               bias=False)
        self.bn1 = nn.BatchNorm2d(16)
        self.layer1 = self._make_layer(16, 2, stride=1)
        self.layer2 = self._make_layer(32, 2, stride=2)
        self.layer3 = self._make_layer(64, 2, stride=2)
        self.linear = nn.Linear(64, num_classes)

    def _make_layer(self, planes, num_blocks, stride) :
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides :
            layers.append(BasicBlock(self.in_planes, planes, stride))
            self.in_planes = planes
        return nn.Sequential(*layers)
    
    def forward(self, x) :
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, 8)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %%
del model

# %%
model = ResNet().to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr = 0.01)
criterion = nn.CrossEntropyLoss()
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
def train(model, train_loader, optimizer, log_intervals = 100) :
    model.train()
    for batch_idx, (image, label) in enumerate(train_loader) :
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        output = model(image)
        optimizer.zero_grad()
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()

        if batch_idx % log_intervals == 0 :
            print('Train_Epoch : {}, [{} / {}]({:.0f}%)\tTrain_loss : {:.6f}'.format(
                Epoch, batch_idx * len(image), len(train_loader.dataset), 
                batch_idx * 100 / len(train_loader), loss.item()
            ))

# %%
def evaluate(model, test_loader) :
    model.eval()
    correct = 0
    test_loss = 0
    with torch.no_grad () :
        for image, label in test_loader :
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss = criterion(output, label) 
            prediction = output.max(1, keepdim=True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()

        test_loss /= len(test_loader.dataset)
        test_accuracy = correct * 100 / len(test_loader.dataset)
        return test_loss, test_accuracy

# %%
es = 0 
best_accuracy = 0

for Epoch in range(1, EPOCHS + 1) :
    train(model, train_loader, optimizer)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print('\nEPOCH : {}, Test_loss : {:.6f}, Test_accuracy : {:.2f}%\n'.format(
        Epoch, test_loss, test_accuracy
    ))

    if test_accuracy > best_accuracy :
        best_accuracy = test_accuracy
        es = 0
        best_model = model
    else :
        es += 1

    if es >= 10 :
        print(best_accuracy)
        break
# Out:
# Train_Epoch : 1, [0 / 50000](0%)	Train_loss : 2.431217
# Train_Epoch : 1, [12800 / 50000](26%)	Train_loss : 1.758827
# Train_Epoch : 1, [25600 / 50000](51%)	Train_loss : 1.380175
# Train_Epoch : 1, [38400 / 50000](77%)	Train_loss : 1.371258
#
# EPOCH : 1, Test_loss : 0.000127, Test_accuracy : 54.50%
#
# Train_Epoch : 2, [0 / 50000](0%)	Train_loss : 1.278360
# Train_Epoch : 2, [12800 / 50000](26%)	Train_loss : 1.002121
# Train_Epoch : 2, [25600 / 50000](51%)	Train_loss : 1.048265
# Train_Epoch : 2, [38400 / 50000](77%)	Train_loss : 0.943573
#
# EPOCH : 2, Test_loss : 0.000087, Test_accuracy : 65.75%
#
# Train_Epoch : 3, [0 / 50000](0%)	Train_loss : 0.931088
# Train_Epoch : 3, [12800 / 50000](26%)	Train_loss : 0.837504
# Train_Epoch : 3, [25600 / 50000](51%)	Train_loss : 0.762137
# Train_Epoch : 3, [38400 / 50000](77%)	Train_loss : 0.621286
#
# EPOCH : 3, Test_loss : 0.000079, Test_accuracy : 68.45%
#
# Train_Epoch : 4, [0 / 50000](0%)	Train_loss : 0.738423
# Train_Epoch : 4, [12800 / 50000](26%)	Train_loss : 0.781937
# Train_Epoch : 4, [25600 / 50000](51%)	Train_loss : 0.881503
# Train_Epoch : 4, [38400 / 50000](77%)	Train_loss : 0.693507
#
# EPOCH : 4, Test_loss : 0.000093, Test_accuracy : 77.71%
#
# Train_Epoch : 5, [0 / 50000](0%)	Train_loss : 0.564014
# Train_Epoch : 5, [12800 / 50000](26%)	Train_loss : 0.604149
# Train_Epoch : 5, [25600 / 50000](51%)	Train_loss : 0.651309
# Train_Epoch : 5, [38400 / 50000](77%)	Train_loss : 0.653423
#
# EPOCH : 5, Test_loss : 0.000079, Test_accuracy : 76.70%
#
# Train_Epoch : 6, [0 / 50000](0%)	Train_loss : 0.555425
# Train_Epoch : 6, [12800 / 50000](26%)	Train_loss : 0.528414
# Train_Epoch : 6, [25600 / 50000](51%)	Train_loss : 0.416265
# Train_Epoch : 6, [38400 / 50000](77%)	Train_loss : 0.588316
#
# EPOCH : 6, Test_loss : 0.000043, Test_accuracy : 78.90%
#
# Train_Epoch : 7, [0 / 50000](0%)	Train_loss : 0.448485
# Train_Epoch : 7, [12800 / 50000](26%)	Train_loss : 0.509135
# Train_Epoch : 7, [25600 / 50000](51%)	Train_loss : 0.540794
# Train_Epoch : 7, [38400 / 50000](77%)	Train_loss : 0.462326
#
# EPOCH : 7, Test_loss : 0.000048, Test_accuracy : 78.76%
#
# Train_Epoch : 8, [0 / 50000](0%)	Train_loss : 0.312559
# Train_Epoch : 8, [12800 / 50000](26%)	Train_loss : 0.491766
# Train_Epoch : 8, [25600 / 50000](51%)	Train_loss : 0.548862
# Train_Epoch : 8, [38400 / 50000](77%)	Train_loss : 0.462796
#
# EPOCH : 8, Test_loss : 0.000055, Test_accuracy : 81.21%
#
# Train_Epoch : 9, [0 / 50000](0%)	Train_loss : 0.516114
# Train_Epoch : 9, [12800 / 50000](26%)	Train_loss : 0.461499
# Train_Epoch : 9, [25600 / 50000](51%)	Train_loss : 0.515909
# Train_Epoch : 9, [38400 / 50000](77%)	Train_loss : 0.406614
#
# EPOCH : 9, Test_loss : 0.000083, Test_accuracy : 80.10%
#
# Train_Epoch : 10, [0 / 50000](0%)	Train_loss : 0.361300
# Train_Epoch : 10, [12800 / 50000](26%)	Train_loss : 0.224943
# Train_Epoch : 10, [25600 / 50000](51%)	Train_loss : 0.355126
# Train_Epoch : 10, [38400 / 50000](77%)	Train_loss : 0.411297
#
# EPOCH : 10, Test_loss : 0.000037, Test_accuracy : 81.49%
#
# Train_Epoch : 11, [0 / 50000](0%)	Train_loss : 0.258452
# Train_Epoch : 11, [12800 / 50000](26%)	Train_loss : 0.346252
# Train_Epoch : 11, [25600 / 50000](51%)	Train_loss : 0.412026
# Train_Epoch : 11, [38400 / 50000](77%)	Train_loss : 0.313211
#
# EPOCH : 11, Test_loss : 0.000080, Test_accuracy : 82.26%
#
# Train_Epoch : 12, [0 / 50000](0%)	Train_loss : 0.350883
# Train_Epoch : 12, [12800 / 50000](26%)	Train_loss : 0.299811
# Train_Epoch : 12, [25600 / 50000](51%)	Train_loss : 0.319658
# Train_Epoch : 12, [38400 / 50000](77%)	Train_loss : 0.382237
#
# EPOCH : 12, Test_loss : 0.000028, Test_accuracy : 81.64%
#
# Train_Epoch : 13, [0 / 50000](0%)	Train_loss : 0.343695
# Train_Epoch : 13, [12800 / 50000](26%)	Train_loss : 0.346462
# Train_Epoch : 13, [25600 / 50000](51%)	Train_loss : 0.374568
# Train_Epoch : 13, [38400 / 50000](77%)	Train_loss : 0.321873
#
# EPOCH : 13, Test_loss : 0.000045, Test_accuracy : 82.09%
#
# Train_Epoch : 14, [0 / 50000](0%)	Train_loss : 0.408510
# Train_Epoch : 14, [12800 / 50000](26%)	Train_loss : 0.273602
# Train_Epoch : 14, [25600 / 50000](51%)	Train_loss : 0.284483
# Train_Epoch : 14, [38400 / 50000](77%)	Train_loss : 0.298345
#
# EPOCH : 14, Test_loss : 0.000079, Test_accuracy : 83.34%
#
# Train_Epoch : 15, [0 / 50000](0%)	Train_loss : 0.224644
# Train_Epoch : 15, [12800 / 50000](26%)	Train_loss : 0.216463
# Train_Epoch : 15, [25600 / 50000](51%)	Train_loss : 0.341304
# Train_Epoch : 15, [38400 / 50000](77%)	Train_loss : 0.392360
#
# EPOCH : 15, Test_loss : 0.000062, Test_accuracy : 83.36%
#
# Train_Epoch : 16, [0 / 50000](0%)	Train_loss : 0.208222
# Train_Epoch : 16, [12800 / 50000](26%)	Train_loss : 0.353986
# Train_Epoch : 16, [25600 / 50000](51%)	Train_loss : 0.280616
# Train_Epoch : 16, [38400 / 50000](77%)	Train_loss : 0.350302
#
# EPOCH : 16, Test_loss : 0.000057, Test_accuracy : 82.04%
#
# Train_Epoch : 17, [0 / 50000](0%)	Train_loss : 0.198624
# Train_Epoch : 17, [12800 / 50000](26%)	Train_loss : 0.204073
# Train_Epoch : 17, [25600 / 50000](51%)	Train_loss : 0.468958
# Train_Epoch : 17, [38400 / 50000](77%)	Train_loss : 0.330253
#
# EPOCH : 17, Test_loss : 0.000021, Test_accuracy : 83.75%
#
# Train_Epoch : 18, [0 / 50000](0%)	Train_loss : 0.211691
# Train_Epoch : 18, [12800 / 50000](26%)	Train_loss : 0.248498
# Train_Epoch : 18, [25600 / 50000](51%)	Train_loss : 0.292530
# Train_Epoch : 18, [38400 / 50000](77%)	Train_loss : 0.304017
#
# EPOCH : 18, Test_loss : 0.000013, Test_accuracy : 83.77%
#
# Train_Epoch : 19, [0 / 50000](0%)	Train_loss : 0.225630
# Train_Epoch : 19, [12800 / 50000](26%)	Train_loss : 0.286680
# Train_Epoch : 19, [25600 / 50000](51%)	Train_loss : 0.206676
# Train_Epoch : 19, [38400 / 50000](77%)	Train_loss : 0.307093
#
# EPOCH : 19, Test_loss : 0.000032, Test_accuracy : 82.96%
#
# Train_Epoch : 20, [0 / 50000](0%)	Train_loss : 0.210427
# Train_Epoch : 20, [12800 / 50000](26%)	Train_loss : 0.164499
# Train_Epoch : 20, [25600 / 50000](51%)	Train_loss : 0.227399
# Train_Epoch : 20, [38400 / 50000](77%)	Train_loss : 0.217690
#
# EPOCH : 20, Test_loss : 0.000093, Test_accuracy : 83.21%
#
# Train_Epoch : 21, [0 / 50000](0%)	Train_loss : 0.200319
# Train_Epoch : 21, [12800 / 50000](26%)	Train_loss : 0.218231
# Train_Epoch : 21, [25600 / 50000](51%)	Train_loss : 0.142206
# Train_Epoch : 21, [38400 / 50000](77%)	Train_loss : 0.231453
#
# EPOCH : 21, Test_loss : 0.000094, Test_accuracy : 82.61%
#
# Train_Epoch : 22, [0 / 50000](0%)	Train_loss : 0.184776
# Train_Epoch : 22, [12800 / 50000](26%)	Train_loss : 0.152067
# Train_Epoch : 22, [25600 / 50000](51%)	Train_loss : 0.192858
# Train_Epoch : 22, [38400 / 50000](77%)	Train_loss : 0.269547
#
# EPOCH : 22, Test_loss : 0.000074, Test_accuracy : 82.72%
#
# Train_Epoch : 23, [0 / 50000](0%)	Train_loss : 0.252722
# Train_Epoch : 23, [12800 / 50000](26%)	Train_loss : 0.117561
# Train_Epoch : 23, [25600 / 50000](51%)	Train_loss : 0.140978
# Train_Epoch : 23, [38400 / 50000](77%)	Train_loss : 0.145684
#
# EPOCH : 23, Test_loss : 0.000098, Test_accuracy : 81.75%
#
# Train_Epoch : 24, [0 / 50000](0%)	Train_loss : 0.213693
# Train_Epoch : 24, [12800 / 50000](26%)	Train_loss : 0.272038
# Train_Epoch : 24, [25600 / 50000](51%)	Train_loss : 0.336788
# Train_Epoch : 24, [38400 / 50000](77%)	Train_loss : 0.184883
#
# EPOCH : 24, Test_loss : 0.000069, Test_accuracy : 83.17%
#
# Train_Epoch : 25, [0 / 50000](0%)	Train_loss : 0.178937
# Train_Epoch : 25, [12800 / 50000](26%)	Train_loss : 0.177687
# Train_Epoch : 25, [25600 / 50000](51%)	Train_loss : 0.136282
# Train_Epoch : 25, [38400 / 50000](77%)	Train_loss : 0.216153
#
# EPOCH : 25, Test_loss : 0.000070, Test_accuracy : 84.72%
#
# Train_Epoch : 26, [0 / 50000](0%)	Train_loss : 0.147149
# Train_Epoch : 26, [12800 / 50000](26%)	Train_loss : 0.218547
# Train_Epoch : 26, [25600 / 50000](51%)	Train_loss : 0.086911
# Train_Epoch : 26, [38400 / 50000](77%)	Train_loss : 0.186294
#
# EPOCH : 26, Test_loss : 0.000039, Test_accuracy : 83.45%
#
# Train_Epoch : 27, [0 / 50000](0%)	Train_loss : 0.158296
# Train_Epoch : 27, [12800 / 50000](26%)	Train_loss : 0.057365
# Train_Epoch : 27, [25600 / 50000](51%)	Train_loss : 0.121683
# Train_Epoch : 27, [38400 / 50000](77%)	Train_loss : 0.187929
#
# EPOCH : 27, Test_loss : 0.000061, Test_accuracy : 83.65%
#
# Train_Epoch : 28, [0 / 50000](0%)	Train_loss : 0.151440
# Train_Epoch : 28, [12800 / 50000](26%)	Train_loss : 0.138654
# Train_Epoch : 28, [25600 / 50000](51%)	Train_loss : 0.136395
# Train_Epoch : 28, [38400 / 50000](77%)	Train_loss : 0.137717
#
# EPOCH : 28, Test_loss : 0.000063, Test_accuracy : 84.37%
#
# Train_Epoch : 29, [0 / 50000](0%)	Train_loss : 0.175490
# Train_Epoch : 29, [12800 / 50000](26%)	Train_loss : 0.112438
# Train_Epoch : 29, [25600 / 50000](51%)	Train_loss : 0.143319
# Train_Epoch : 29, [38400 / 50000](77%)	Train_loss : 0.122405
#
# EPOCH : 29, Test_loss : 0.000053, Test_accuracy : 84.27%
#
# Train_Epoch : 30, [0 / 50000](0%)	Train_loss : 0.192937
# Train_Epoch : 30, [12800 / 50000](26%)	Train_loss : 0.099794
# Train_Epoch : 30, [25600 / 50000](51%)	Train_loss : 0.079595
# Train_Epoch : 30, [38400 / 50000](77%)	Train_loss : 0.105523
#
# EPOCH : 30, Test_loss : 0.000059, Test_accuracy : 83.79%
#
# Train_Epoch : 31, [0 / 50000](0%)	Train_loss : 0.151151
# Train_Epoch : 31, [12800 / 50000](26%)	Train_loss : 0.092407
# Train_Epoch : 31, [25600 / 50000](51%)	Train_loss : 0.126484
# Train_Epoch : 31, [38400 / 50000](77%)	Train_loss : 0.173156
#
# EPOCH : 31, Test_loss : 0.000028, Test_accuracy : 82.69%
#
# Train_Epoch : 32, [0 / 50000](0%)	Train_loss : 0.073157
# Train_Epoch : 32, [12800 / 50000](26%)	Train_loss : 0.083903
# Train_Epoch : 32, [25600 / 50000](51%)	Train_loss : 0.121876
# Train_Epoch : 32, [38400 / 50000](77%)	Train_loss : 0.074565
#
# EPOCH : 32, Test_loss : 0.000048, Test_accuracy : 84.92%
#
# Train_Epoch : 33, [0 / 50000](0%)	Train_loss : 0.065730
# Train_Epoch : 33, [12800 / 50000](26%)	Train_loss : 0.098196
# Train_Epoch : 33, [25600 / 50000](51%)	Train_loss : 0.093946
# Train_Epoch : 33, [38400 / 50000](77%)	Train_loss : 0.099712
#
# EPOCH : 33, Test_loss : 0.000031, Test_accuracy : 84.44%
#
# Train_Epoch : 34, [0 / 50000](0%)	Train_loss : 0.090606
# Train_Epoch : 34, [12800 / 50000](26%)	Train_loss : 0.071970
# Train_Epoch : 34, [25600 / 50000](51%)	Train_loss : 0.050670
# Train_Epoch : 34, [38400 / 50000](77%)	Train_loss : 0.132834
#
# EPOCH : 34, Test_loss : 0.000090, Test_accuracy : 84.27%
#
# Train_Epoch : 35, [0 / 50000](0%)	Train_loss : 0.097178
# Train_Epoch : 35, [12800 / 50000](26%)	Train_loss : 0.061093
# Train_Epoch : 35, [25600 / 50000](51%)	Train_loss : 0.055737
# Train_Epoch : 35, [38400 / 50000](77%)	Train_loss : 0.101591
#
# EPOCH : 35, Test_loss : 0.000063, Test_accuracy : 83.86%
#
# Train_Epoch : 36, [0 / 50000](0%)	Train_loss : 0.039238
# Train_Epoch : 36, [12800 / 50000](26%)	Train_loss : 0.075634
# Train_Epoch : 36, [25600 / 50000](51%)	Train_loss : 0.108360
# Train_Epoch : 36, [38400 / 50000](77%)	Train_loss : 0.155239
#
# EPOCH : 36, Test_loss : 0.000107, Test_accuracy : 82.63%
#
# Train_Epoch : 37, [0 / 50000](0%)	Train_loss : 0.064167
# Train_Epoch : 37, [12800 / 50000](26%)	Train_loss : 0.084475
# Train_Epoch : 37, [25600 / 50000](51%)	Train_loss : 0.103124
# Train_Epoch : 37, [38400 / 50000](77%)	Train_loss : 0.109208
#
# EPOCH : 37, Test_loss : 0.000135, Test_accuracy : 83.82%
#
# Train_Epoch : 38, [0 / 50000](0%)	Train_loss : 0.075354
# Train_Epoch : 38, [12800 / 50000](26%)	Train_loss : 0.095422
# Train_Epoch : 38, [25600 / 50000](51%)	Train_loss : 0.066391
# Train_Epoch : 38, [38400 / 50000](77%)	Train_loss : 0.057540
#
# EPOCH : 38, Test_loss : 0.000088, Test_accuracy : 84.19%
#
# Train_Epoch : 39, [0 / 50000](0%)	Train_loss : 0.123474
# Train_Epoch : 39, [12800 / 50000](26%)	Train_loss : 0.055859
# Train_Epoch : 39, [25600 / 50000](51%)	Train_loss : 0.136036
# Train_Epoch : 39, [38400 / 50000](77%)	Train_loss : 0.056603
#
# EPOCH : 39, Test_loss : 0.000073, Test_accuracy : 84.30%
#
# Train_Epoch : 40, [0 / 50000](0%)	Train_loss : 0.028638
# Train_Epoch : 40, [12800 / 50000](26%)	Train_loss : 0.051965
# Train_Epoch : 40, [25600 / 50000](51%)	Train_loss : 0.051820
# Train_Epoch : 40, [38400 / 50000](77%)	Train_loss : 0.061262
#
# EPOCH : 40, Test_loss : 0.000096, Test_accuracy : 83.27%
#
# Train_Epoch : 41, [0 / 50000](0%)	Train_loss : 0.048900
# Train_Epoch : 41, [12800 / 50000](26%)	Train_loss : 0.078847
# Train_Epoch : 41, [25600 / 50000](51%)	Train_loss : 0.032084
# Train_Epoch : 41, [38400 / 50000](77%)	Train_loss : 0.041317
#
# EPOCH : 41, Test_loss : 0.000080, Test_accuracy : 83.76%
#
# Train_Epoch : 42, [0 / 50000](0%)	Train_loss : 0.058635
# Train_Epoch : 42, [12800 / 50000](26%)	Train_loss : 0.035739
# Train_Epoch : 42, [25600 / 50000](51%)	Train_loss : 0.045058
# Train_Epoch : 42, [38400 / 50000](77%)	Train_loss : 0.191849
#
# EPOCH : 42, Test_loss : 0.000103, Test_accuracy : 84.07%
#
# 84.92

# %% [markdown]
# # 파이토치내 제공모델 불러와 학습

# %%
import torchvision.models as models
model2 = models.resnet34(pretrained = False)
# 해당하는 in_features 노드 수 받기
num_fts = model2.fc.in_features
# 아웃풋 값 조정
model2.fc = nn.Linear(num_fts, 10)
model2 = model.cuda()
# Out:
# c:\Users\Admin\anaconda3\envs\pytorch\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Admin\anaconda3\envs\pytorch\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
es = 0 
best_accuracy = 0

for Epoch in range(1, EPOCHS + 1) :
    train(model2, train_loader, optimizer)
    test_loss, test_accuracy = evaluate(model2, test_loader)
    print('\nEPOCH : {}, Test_loss : {:.6f}, Test_accuracy : {:.2f}%\n'.format(
        Epoch, test_loss, test_accuracy
    ))

    if test_accuracy > best_accuracy :
        best_accuracy = test_accuracy
        es = 0
        best_model = model2
    else :
        es += 1

    if es >= 10 :
        print(best_accuracy)
        break
# Out:
# Train_Epoch : 1, [0 / 50000](0%)	Train_loss : 0.093986
# Train_Epoch : 1, [12800 / 50000](26%)	Train_loss : 0.054162
# Train_Epoch : 1, [25600 / 50000](51%)	Train_loss : 0.107896
# Train_Epoch : 1, [38400 / 50000](77%)	Train_loss : 0.119800
#
# EPOCH : 1, Test_loss : 0.000128, Test_accuracy : 84.29%
#
# Train_Epoch : 2, [0 / 50000](0%)	Train_loss : 0.043868
# Train_Epoch : 2, [12800 / 50000](26%)	Train_loss : 0.072611
# Train_Epoch : 2, [25600 / 50000](51%)	Train_loss : 0.078866
# Train_Epoch : 2, [38400 / 50000](77%)	Train_loss : 0.071546
#
# EPOCH : 2, Test_loss : 0.000135, Test_accuracy : 84.49%
#
# Train_Epoch : 3, [0 / 50000](0%)	Train_loss : 0.104631
# Train_Epoch : 3, [12800 / 50000](26%)	Train_loss : 0.072675
# Train_Epoch : 3, [25600 / 50000](51%)	Train_loss : 0.059070
# Train_Epoch : 3, [38400 / 50000](77%)	Train_loss : 0.094821
#
# EPOCH : 3, Test_loss : 0.000076, Test_accuracy : 84.06%
#
# Train_Epoch : 4, [0 / 50000](0%)	Train_loss : 0.080825
# Train_Epoch : 4, [12800 / 50000](26%)	Train_loss : 0.146504
# Train_Epoch : 4, [25600 / 50000](51%)	Train_loss : 0.044417
# Train_Epoch : 4, [38400 / 50000](77%)	Train_loss : 0.070571
#
# EPOCH : 4, Test_loss : 0.000130, Test_accuracy : 82.53%
#
# Train_Epoch : 5, [0 / 50000](0%)	Train_loss : 0.107642
# Train_Epoch : 5, [12800 / 50000](26%)	Train_loss : 0.023506
# Train_Epoch : 5, [25600 / 50000](51%)	Train_loss : 0.043339
# Train_Epoch : 5, [38400 / 50000](77%)	Train_loss : 0.052666
#
# EPOCH : 5, Test_loss : 0.000091, Test_accuracy : 84.86%
#
# Train_Epoch : 6, [0 / 50000](0%)	Train_loss : 0.031072
# Train_Epoch : 6, [12800 / 50000](26%)	Train_loss : 0.028135
# Train_Epoch : 6, [25600 / 50000](51%)	Train_loss : 0.031437
# Train_Epoch : 6, [38400 / 50000](77%)	Train_loss : 0.039658
#
# EPOCH : 6, Test_loss : 0.000086, Test_accuracy : 83.76%
#
# Train_Epoch : 7, [0 / 50000](0%)	Train_loss : 0.134113
# Train_Epoch : 7, [12800 / 50000](26%)	Train_loss : 0.069949
# Train_Epoch : 7, [25600 / 50000](51%)	Train_loss : 0.037154
# Train_Epoch : 7, [38400 / 50000](77%)	Train_loss : 0.094007
#
# EPOCH : 7, Test_loss : 0.000093, Test_accuracy : 84.78%
#
# Train_Epoch : 8, [0 / 50000](0%)	Train_loss : 0.090431
# Train_Epoch : 8, [12800 / 50000](26%)	Train_loss : 0.038252
# Train_Epoch : 8, [25600 / 50000](51%)	Train_loss : 0.039223
# Train_Epoch : 8, [38400 / 50000](77%)	Train_loss : 0.084560
#
# EPOCH : 8, Test_loss : 0.000158, Test_accuracy : 84.31%
#
# Train_Epoch : 9, [0 / 50000](0%)	Train_loss : 0.105524
# Train_Epoch : 9, [12800 / 50000](26%)	Train_loss : 0.016564
# Train_Epoch : 9, [25600 / 50000](51%)	Train_loss : 0.088813
# Train_Epoch : 9, [38400 / 50000](77%)	Train_loss : 0.052306
#
# EPOCH : 9, Test_loss : 0.000125, Test_accuracy : 84.01%
#
# Train_Epoch : 10, [0 / 50000](0%)	Train_loss : 0.130024
# Train_Epoch : 10, [12800 / 50000](26%)	Train_loss : 0.050739
# Train_Epoch : 10, [25600 / 50000](51%)	Train_loss : 0.079651
# Train_Epoch : 10, [38400 / 50000](77%)	Train_loss : 0.034255
#
# EPOCH : 10, Test_loss : 0.000098, Test_accuracy : 84.81%
#
# Train_Epoch : 11, [0 / 50000](0%)	Train_loss : 0.038108
# Train_Epoch : 11, [12800 / 50000](26%)	Train_loss : 0.075223
# Train_Epoch : 11, [25600 / 50000](51%)	Train_loss : 0.008235
# Train_Epoch : 11, [38400 / 50000](77%)	Train_loss : 0.052940
#
# EPOCH : 11, Test_loss : 0.000055, Test_accuracy : 84.86%
#
# Train_Epoch : 12, [0 / 50000](0%)	Train_loss : 0.051350
# Train_Epoch : 12, [12800 / 50000](26%)	Train_loss : 0.054655
# Train_Epoch : 12, [25600 / 50000](51%)	Train_loss : 0.087148
# Train_Epoch : 12, [38400 / 50000](77%)	Train_loss : 0.043229
#
# EPOCH : 12, Test_loss : 0.000103, Test_accuracy : 84.22%
#
# Train_Epoch : 13, [0 / 50000](0%)	Train_loss : 0.097923
# Train_Epoch : 13, [12800 / 50000](26%)	Train_loss : 0.024267
# Train_Epoch : 13, [25600 / 50000](51%)	Train_loss : 0.050871
# Train_Epoch : 13, [38400 / 50000](77%)	Train_loss : 0.039369
#
# EPOCH : 13, Test_loss : 0.000101, Test_accuracy : 84.94%
#
# Train_Epoch : 14, [0 / 50000](0%)	Train_loss : 0.091893
# Train_Epoch : 14, [12800 / 50000](26%)	Train_loss : 0.040046
# Train_Epoch : 14, [25600 / 50000](51%)	Train_loss : 0.046436
# Train_Epoch : 14, [38400 / 50000](77%)	Train_loss : 0.079744
#
# EPOCH : 14, Test_loss : 0.000093, Test_accuracy : 83.66%
#
# Train_Epoch : 15, [0 / 50000](0%)	Train_loss : 0.032789
# Train_Epoch : 15, [12800 / 50000](26%)	Train_loss : 0.019243
# Train_Epoch : 15, [25600 / 50000](51%)	Train_loss : 0.029289
# Train_Epoch : 15, [38400 / 50000](77%)	Train_loss : 0.076454
#
# EPOCH : 15, Test_loss : 0.000078, Test_accuracy : 84.76%
#
# Train_Epoch : 16, [0 / 50000](0%)	Train_loss : 0.016199
# Train_Epoch : 16, [12800 / 50000](26%)	Train_loss : 0.048263
# Train_Epoch : 16, [25600 / 50000](51%)	Train_loss : 0.033596
# Train_Epoch : 16, [38400 / 50000](77%)	Train_loss : 0.234844
#
# EPOCH : 16, Test_loss : 0.000061, Test_accuracy : 84.41%
#
# Train_Epoch : 17, [0 / 50000](0%)	Train_loss : 0.036490
# Train_Epoch : 17, [12800 / 50000](26%)	Train_loss : 0.028806
# Train_Epoch : 17, [25600 / 50000](51%)	Train_loss : 0.060831
# Train_Epoch : 17, [38400 / 50000](77%)	Train_loss : 0.047079
#
# EPOCH : 17, Test_loss : 0.000112, Test_accuracy : 84.80%
#
# Train_Epoch : 18, [0 / 50000](0%)	Train_loss : 0.036557
# Train_Epoch : 18, [12800 / 50000](26%)	Train_loss : 0.066956
# Train_Epoch : 18, [25600 / 50000](51%)	Train_loss : 0.048513
# Train_Epoch : 18, [38400 / 50000](77%)	Train_loss : 0.066529
#
# EPOCH : 18, Test_loss : 0.000145, Test_accuracy : 84.36%
#
# Train_Epoch : 19, [0 / 50000](0%)	Train_loss : 0.052929
# Train_Epoch : 19, [12800 / 50000](26%)	Train_loss : 0.044122
# Train_Epoch : 19, [25600 / 50000](51%)	Train_loss : 0.036044
# Train_Epoch : 19, [38400 / 50000](77%)	Train_loss : 0.090975
#
# EPOCH : 19, Test_loss : 0.000033, Test_accuracy : 84.98%
#
# Train_Epoch : 20, [0 / 50000](0%)	Train_loss : 0.037000
# Train_Epoch : 20, [12800 / 50000](26%)	Train_loss : 0.019836
# Train_Epoch : 20, [25600 / 50000](51%)	Train_loss : 0.083574
# Train_Epoch : 20, [38400 / 50000](77%)	Train_loss : 0.085456
#
# EPOCH : 20, Test_loss : 0.000100, Test_accuracy : 84.32%
#
# Train_Epoch : 21, [0 / 50000](0%)	Train_loss : 0.028924
# Train_Epoch : 21, [12800 / 50000](26%)	Train_loss : 0.051796
# Train_Epoch : 21, [25600 / 50000](51%)	Train_loss : 0.039408
# Train_Epoch : 21, [38400 / 50000](77%)	Train_loss : 0.029254
#
# EPOCH : 21, Test_loss : 0.000112, Test_accuracy : 84.44%
#
# Train_Epoch : 22, [0 / 50000](0%)	Train_loss : 0.108770
# Train_Epoch : 22, [12800 / 50000](26%)	Train_loss : 0.035982
# Train_Epoch : 22, [25600 / 50000](51%)	Train_loss : 0.066921
# Train_Epoch : 22, [38400 / 50000](77%)	Train_loss : 0.089507
#
# EPOCH : 22, Test_loss : 0.000123, Test_accuracy : 84.09%
#
# Train_Epoch : 23, [0 / 50000](0%)	Train_loss : 0.059464
# Train_Epoch : 23, [12800 / 50000](26%)	Train_loss : 0.059619
# Train_Epoch : 23, [25600 / 50000](51%)	Train_loss : 0.039170
# Train_Epoch : 23, [38400 / 50000](77%)	Train_loss : 0.066517
#
# EPOCH : 23, Test_loss : 0.000161, Test_accuracy : 84.40%
#
# Train_Epoch : 24, [0 / 50000](0%)	Train_loss : 0.032757
# Train_Epoch : 24, [12800 / 50000](26%)	Train_loss : 0.044366
# Train_Epoch : 24, [25600 / 50000](51%)	Train_loss : 0.067599
# Train_Epoch : 24, [38400 / 50000](77%)	Train_loss : 0.075466
#
# EPOCH : 24, Test_loss : 0.000119, Test_accuracy : 84.38%
#
# Train_Epoch : 25, [0 / 50000](0%)	Train_loss : 0.039489
# Train_Epoch : 25, [12800 / 50000](26%)	Train_loss : 0.085319
# Train_Epoch : 25, [25600 / 50000](51%)	Train_loss : 0.045148
# Train_Epoch : 25, [38400 / 50000](77%)	Train_loss : 0.029381
#
# EPOCH : 25, Test_loss : 0.000129, Test_accuracy : 84.31%
#
# Train_Epoch : 26, [0 / 50000](0%)	Train_loss : 0.039452
# Train_Epoch : 26, [12800 / 50000](26%)	Train_loss : 0.065603
# Train_Epoch : 26, [25600 / 50000](51%)	Train_loss : 0.061159
# Train_Epoch : 26, [38400 / 50000](77%)	Train_loss : 0.023144
#
# EPOCH : 26, Test_loss : 0.000076, Test_accuracy : 85.00%
#
# Train_Epoch : 27, [0 / 50000](0%)	Train_loss : 0.052571
# Train_Epoch : 27, [12800 / 50000](26%)	Train_loss : 0.078086
# Train_Epoch : 27, [25600 / 50000](51%)	Train_loss : 0.064039
# Train_Epoch : 27, [38400 / 50000](77%)	Train_loss : 0.052544
#
# EPOCH : 27, Test_loss : 0.000091, Test_accuracy : 84.56%
#
# Train_Epoch : 28, [0 / 50000](0%)	Train_loss : 0.106015
# Train_Epoch : 28, [12800 / 50000](26%)	Train_loss : 0.028069
# Train_Epoch : 28, [25600 / 50000](51%)	Train_loss : 0.065593
# Train_Epoch : 28, [38400 / 50000](77%)	Train_loss : 0.019907
#
# EPOCH : 28, Test_loss : 0.000102, Test_accuracy : 84.72%
#
# Train_Epoch : 29, [0 / 50000](0%)	Train_loss : 0.018420
# Train_Epoch : 29, [12800 / 50000](26%)	Train_loss : 0.060261
# Train_Epoch : 29, [25600 / 50000](51%)	Train_loss : 0.055221
# Train_Epoch : 29, [38400 / 50000](77%)	Train_loss : 0.038201
#
# EPOCH : 29, Test_loss : 0.000079, Test_accuracy : 84.47%
#
# Train_Epoch : 30, [0 / 50000](0%)	Train_loss : 0.028765
# Train_Epoch : 30, [12800 / 50000](26%)	Train_loss : 0.045952
# Train_Epoch : 30, [25600 / 50000](51%)	Train_loss : 0.086359
# Train_Epoch : 30, [38400 / 50000](77%)	Train_loss : 0.019048
#
# EPOCH : 30, Test_loss : 0.000093, Test_accuracy : 84.49%
#
# Train_Epoch : 31, [0 / 50000](0%)	Train_loss : 0.037976
# Train_Epoch : 31, [12800 / 50000](26%)	Train_loss : 0.067243
# Train_Epoch : 31, [25600 / 50000](51%)	Train_loss : 0.050750
# Train_Epoch : 31, [38400 / 50000](77%)	Train_loss : 0.094890
#
# EPOCH : 31, Test_loss : 0.000089, Test_accuracy : 85.11%
#
# Train_Epoch : 32, [0 / 50000](0%)	Train_loss : 0.029704
# Train_Epoch : 32, [12800 / 50000](26%)	Train_loss : 0.035170
# Train_Epoch : 32, [25600 / 50000](51%)	Train_loss : 0.064536
