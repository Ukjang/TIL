# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

import torch 
import torch.nn as nn 
import torch.nn.functional as F 
from torchvision import datasets, transforms

# %%
BATCH_SIZE = 128
EPOCHS = 100

# %%
if torch.cuda.is_available() :
    DEVICE = torch.device('cuda')
else :
    DEVICE = torch.device('cpu')
print(DEVICE, torch.cuda.get_device_name(), f'torch : {torch.__version__}')
# Out:
# cuda NVIDIA GeForce GTX 1650 torch : 1.12.1+cu113

# %%
train_dataset = datasets.CIFAR10(root = '../../data/cifar10',
                                 download=True,
                                 train=True,
                                 transform= transforms.Compose([
                                    transforms.RandomHorizontalFlip(),
                                    transforms.ToTensor(),
                                    transforms.Normalize((0.5, 0.5, 0.5),
                                                         (0.5, 0.5, 0.5))
                                 ]))
test_dataset = datasets.CIFAR10(root = '../../data/cifar10',
                                 download=True,
                                 train=False,
                                 transform= transforms.Compose([
                                    transforms.RandomHorizontalFlip(),
                                    transforms.ToTensor(),
                                    transforms.Normalize((0.5, 0.5, 0.5),
                                                         (0.5, 0.5, 0.5))
                                 ]))
train_loader = torch.utils.data.DataLoader(train_dataset,
                                           shuffle=True,
                                           batch_size = BATCH_SIZE)
test_loader = torch.utils.data.DataLoader(test_dataset,
                                           shuffle=False,
                                           batch_size = BATCH_SIZE)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
for (X_train, y_train) in train_loader :
    print(X_train.size(), y_train.size())
    print(X_train.type(), y_train.type())
    break
# Out:
# torch.Size([128, 3, 32, 32]) torch.Size([128])
# torch.FloatTensor torch.LongTensor

# %%
pltsize = 1
plt.figure(figsize = (pltsize*10, pltsize))
for i in range(10) :
    plt.subplot(1, 10, i+1)
    plt.axis('off')
    plt.imshow(np.transpose(X_train[i], (1, 2, 0)))
    plt.title('Class :' + str(y_train[i].item()))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class BasicBlock(nn.Module) :
    def __init__(self, in_planes, planes, stride=1) :
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes,
                               kernel_size=3,
                               stride=stride,
                               padding=1,
                               bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes,
                               kernel_size=3,
                               stride = 1,
                               padding=1,
                               bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.shortcut = nn.Sequential()

        if in_planes != planes or stride != 1 :
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes,
                          kernel_size=1,
                          stride=stride,
                          bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x) :
        out = self.bn1(self.conv1(x))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out
    

class ResNet(nn.Module) :
    def __init__(self, num_classes = 10) :
        super(ResNet, self).__init__()
        self.in_planes = 16
        
        self.conv1 = nn.Conv2d(3, 16,
                                kernel_size=3,
                                stride = 1,
                                padding = 1,
                                bias = False)
        self.bn1 = nn.BatchNorm2d(16)
        self.layer1 = self._make_layer(16, 6, 1)
        self.layer2 = self._make_layer(32, 6, 2)
        self.layer3 = self._make_layer(64, 6, 2)
        self.linear = nn.Linear(64, num_classes)

    def _make_layer(self, planes, blocks, stride) :
        strides = [stride] + [1] * (blocks - 1)
        layers = []
        for stride in strides :
            layers.append(BasicBlock(self.in_planes, planes, stride=stride))
            self.in_planes = planes
        return nn.Sequential(*layers)
    
    def forward(self, x) :
        out = self.bn1(self.conv1(x))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, 8)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %%
model = ResNet().to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr = 0.01)
criterion = nn.CrossEntropyLoss()
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
def train(model, train_loader, optimizer, log_intervals = 50) :
    model.train()

    for batch_idx, (image, label) in enumerate(train_loader) :
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        output = model(image)
        optimizer.zero_grad()
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()
        
        if batch_idx % log_intervals == 0 :
            print('Train_Epoch : {}, [{} / {}]({:.0f}%), Train_loss : {:.6f}'.format(
                Epoch, batch_idx * len(image), len(train_loader.dataset),
                batch_idx * 100 / len(train_loader), loss.item()
            ))

# %%
def evaluate(model, test_loader) :
    model.eval()
    test_loss = 0
    correct = 0 

    with torch.no_grad() :
        for image, label in test_loader :
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss = criterion(output, label)
            prediction = output.max(1, keepdim=True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()

        test_loss /= len(test_loader.dataset)
        test_accuracy = correct * 100/ len(test_loader.dataset)

        return test_loss, test_accuracy

# %%
es = 0 
best_accuracy = 0

for Epoch in range(1, EPOCHS + 1) :
    train(model, train_loader, optimizer)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print('\nEPOCH : {}, Test_loss : {:.6f}, Test_accuracy : {:.2f}%\n'.format(
        Epoch, test_loss, test_accuracy
    ))

    if test_accuracy > best_accuracy :
        best_accuracy = test_accuracy
        es = 0
        best_model = model
    else :
        es += 1 

    if es >= 10 :
        print(best_accuracy)
        break
# Out:
# Train_Epoch : 1, [0 / 50000](0%), Train_loss : 2.523218
# Train_Epoch : 1, [6400 / 50000](13%), Train_loss : 1.894915
# Train_Epoch : 1, [12800 / 50000](26%), Train_loss : 1.833660
# Train_Epoch : 1, [19200 / 50000](38%), Train_loss : 1.586544
# Train_Epoch : 1, [25600 / 50000](51%), Train_loss : 1.672386
# Train_Epoch : 1, [32000 / 50000](64%), Train_loss : 1.422442
# Train_Epoch : 1, [38400 / 50000](77%), Train_loss : 1.519713
# Train_Epoch : 1, [44800 / 50000](90%), Train_loss : 1.434289
#
# EPOCH : 1, Test_loss : 0.000178, Test_accuracy : 42.14%
#
# Train_Epoch : 2, [0 / 50000](0%), Train_loss : 1.413395
# Train_Epoch : 2, [6400 / 50000](13%), Train_loss : 1.210850
# Train_Epoch : 2, [12800 / 50000](26%), Train_loss : 1.191246
# Train_Epoch : 2, [19200 / 50000](38%), Train_loss : 1.144172
# Train_Epoch : 2, [25600 / 50000](51%), Train_loss : 1.187125
# Train_Epoch : 2, [32000 / 50000](64%), Train_loss : 1.099076
# Train_Epoch : 2, [38400 / 50000](77%), Train_loss : 1.240773
# Train_Epoch : 2, [44800 / 50000](90%), Train_loss : 1.070894
#
# EPOCH : 2, Test_loss : 0.000133, Test_accuracy : 60.10%
#
# Train_Epoch : 3, [0 / 50000](0%), Train_loss : 0.911504
# Train_Epoch : 3, [6400 / 50000](13%), Train_loss : 1.040894
# Train_Epoch : 3, [12800 / 50000](26%), Train_loss : 1.197801
# Train_Epoch : 3, [19200 / 50000](38%), Train_loss : 1.106915
# Train_Epoch : 3, [25600 / 50000](51%), Train_loss : 0.948850
# Train_Epoch : 3, [32000 / 50000](64%), Train_loss : 1.007216
# Train_Epoch : 3, [38400 / 50000](77%), Train_loss : 1.018735
# Train_Epoch : 3, [44800 / 50000](90%), Train_loss : 0.826460
#
# EPOCH : 3, Test_loss : 0.000136, Test_accuracy : 63.58%
#
# Train_Epoch : 4, [0 / 50000](0%), Train_loss : 0.872343
# Train_Epoch : 4, [6400 / 50000](13%), Train_loss : 0.841205
# Train_Epoch : 4, [12800 / 50000](26%), Train_loss : 0.904530
# Train_Epoch : 4, [19200 / 50000](38%), Train_loss : 0.784720
# Train_Epoch : 4, [25600 / 50000](51%), Train_loss : 0.813422
# Train_Epoch : 4, [32000 / 50000](64%), Train_loss : 0.852438
# Train_Epoch : 4, [38400 / 50000](77%), Train_loss : 0.648554
# Train_Epoch : 4, [44800 / 50000](90%), Train_loss : 0.995762
#
# EPOCH : 4, Test_loss : 0.000103, Test_accuracy : 67.82%
#
# Train_Epoch : 5, [0 / 50000](0%), Train_loss : 0.775406
# Train_Epoch : 5, [6400 / 50000](13%), Train_loss : 0.871708
# Train_Epoch : 5, [12800 / 50000](26%), Train_loss : 0.825115
# Train_Epoch : 5, [19200 / 50000](38%), Train_loss : 0.813986
# Train_Epoch : 5, [25600 / 50000](51%), Train_loss : 0.859834
# Train_Epoch : 5, [32000 / 50000](64%), Train_loss : 0.812472
# Train_Epoch : 5, [38400 / 50000](77%), Train_loss : 0.870053
# Train_Epoch : 5, [44800 / 50000](90%), Train_loss : 0.745774
#
# EPOCH : 5, Test_loss : 0.000063, Test_accuracy : 70.40%
#
# Train_Epoch : 6, [0 / 50000](0%), Train_loss : 0.605572
# Train_Epoch : 6, [6400 / 50000](13%), Train_loss : 0.712347
# Train_Epoch : 6, [12800 / 50000](26%), Train_loss : 0.580759
# Train_Epoch : 6, [19200 / 50000](38%), Train_loss : 0.718872
# Train_Epoch : 6, [25600 / 50000](51%), Train_loss : 0.707345
# Train_Epoch : 6, [32000 / 50000](64%), Train_loss : 0.698335
# Train_Epoch : 6, [38400 / 50000](77%), Train_loss : 0.579033
# Train_Epoch : 6, [44800 / 50000](90%), Train_loss : 0.564066
#
# EPOCH : 6, Test_loss : 0.000061, Test_accuracy : 74.82%
#
# Train_Epoch : 7, [0 / 50000](0%), Train_loss : 0.495581
# Train_Epoch : 7, [6400 / 50000](13%), Train_loss : 0.759391
# Train_Epoch : 7, [12800 / 50000](26%), Train_loss : 0.718612
# Train_Epoch : 7, [19200 / 50000](38%), Train_loss : 0.541994
# Train_Epoch : 7, [25600 / 50000](51%), Train_loss : 0.752266
# Train_Epoch : 7, [32000 / 50000](64%), Train_loss : 0.648289
# Train_Epoch : 7, [38400 / 50000](77%), Train_loss : 0.551818
# Train_Epoch : 7, [44800 / 50000](90%), Train_loss : 0.606230
#
# EPOCH : 7, Test_loss : 0.000065, Test_accuracy : 77.80%
#
# Train_Epoch : 8, [0 / 50000](0%), Train_loss : 0.549532
# Train_Epoch : 8, [6400 / 50000](13%), Train_loss : 0.583264
# Train_Epoch : 8, [12800 / 50000](26%), Train_loss : 0.449040
# Train_Epoch : 8, [19200 / 50000](38%), Train_loss : 0.572010
# Train_Epoch : 8, [25600 / 50000](51%), Train_loss : 0.576984
# Train_Epoch : 8, [32000 / 50000](64%), Train_loss : 0.559353
# Train_Epoch : 8, [38400 / 50000](77%), Train_loss : 0.358635
# Train_Epoch : 8, [44800 / 50000](90%), Train_loss : 0.635349
#
# EPOCH : 8, Test_loss : 0.000085, Test_accuracy : 73.91%
#
# Train_Epoch : 9, [0 / 50000](0%), Train_loss : 0.557119
# Train_Epoch : 9, [6400 / 50000](13%), Train_loss : 0.406195
# Train_Epoch : 9, [12800 / 50000](26%), Train_loss : 0.737668
# Train_Epoch : 9, [19200 / 50000](38%), Train_loss : 0.566160
# Train_Epoch : 9, [25600 / 50000](51%), Train_loss : 0.479906
# Train_Epoch : 9, [32000 / 50000](64%), Train_loss : 0.476267
# Train_Epoch : 9, [38400 / 50000](77%), Train_loss : 0.562291
# Train_Epoch : 9, [44800 / 50000](90%), Train_loss : 0.609445
#
# EPOCH : 9, Test_loss : 0.000084, Test_accuracy : 78.06%
#
# Train_Epoch : 10, [0 / 50000](0%), Train_loss : 0.594422
# Train_Epoch : 10, [6400 / 50000](13%), Train_loss : 0.602183
# Train_Epoch : 10, [12800 / 50000](26%), Train_loss : 0.570792
# Train_Epoch : 10, [19200 / 50000](38%), Train_loss : 0.515706
# Train_Epoch : 10, [25600 / 50000](51%), Train_loss : 0.522006
# Train_Epoch : 10, [32000 / 50000](64%), Train_loss : 0.480178
# Train_Epoch : 10, [38400 / 50000](77%), Train_loss : 0.508209
# Train_Epoch : 10, [44800 / 50000](90%), Train_loss : 0.484720
#
# EPOCH : 10, Test_loss : 0.000099, Test_accuracy : 76.72%
#
# Train_Epoch : 11, [0 / 50000](0%), Train_loss : 0.318212
# Train_Epoch : 11, [6400 / 50000](13%), Train_loss : 0.405130
# Train_Epoch : 11, [12800 / 50000](26%), Train_loss : 0.443817
# Train_Epoch : 11, [19200 / 50000](38%), Train_loss : 0.466167
# Train_Epoch : 11, [25600 / 50000](51%), Train_loss : 0.493769
# Train_Epoch : 11, [32000 / 50000](64%), Train_loss : 0.502791
# Train_Epoch : 11, [38400 / 50000](77%), Train_loss : 0.415031
# Train_Epoch : 11, [44800 / 50000](90%), Train_loss : 0.382686
#
# EPOCH : 11, Test_loss : 0.000062, Test_accuracy : 78.95%
#
# Train_Epoch : 12, [0 / 50000](0%), Train_loss : 0.429093
# Train_Epoch : 12, [6400 / 50000](13%), Train_loss : 0.444301
# Train_Epoch : 12, [12800 / 50000](26%), Train_loss : 0.424547
# Train_Epoch : 12, [19200 / 50000](38%), Train_loss : 0.457595
# Train_Epoch : 12, [25600 / 50000](51%), Train_loss : 0.447070
# Train_Epoch : 12, [32000 / 50000](64%), Train_loss : 0.407464
# Train_Epoch : 12, [38400 / 50000](77%), Train_loss : 0.533258
# Train_Epoch : 12, [44800 / 50000](90%), Train_loss : 0.516442
#
# EPOCH : 12, Test_loss : 0.000079, Test_accuracy : 78.71%
#
# Train_Epoch : 13, [0 / 50000](0%), Train_loss : 0.363875
# Train_Epoch : 13, [6400 / 50000](13%), Train_loss : 0.399561
# Train_Epoch : 13, [12800 / 50000](26%), Train_loss : 0.457224
# Train_Epoch : 13, [19200 / 50000](38%), Train_loss : 0.547982
# Train_Epoch : 13, [25600 / 50000](51%), Train_loss : 0.415563
# Train_Epoch : 13, [32000 / 50000](64%), Train_loss : 0.510118
# Train_Epoch : 13, [38400 / 50000](77%), Train_loss : 0.364125
# Train_Epoch : 13, [44800 / 50000](90%), Train_loss : 0.433137
#
# EPOCH : 13, Test_loss : 0.000078, Test_accuracy : 79.92%
#
# Train_Epoch : 14, [0 / 50000](0%), Train_loss : 0.470532
# Train_Epoch : 14, [6400 / 50000](13%), Train_loss : 0.372189
# Train_Epoch : 14, [12800 / 50000](26%), Train_loss : 0.426459
# Train_Epoch : 14, [19200 / 50000](38%), Train_loss : 0.333135
# Train_Epoch : 14, [25600 / 50000](51%), Train_loss : 0.484104
# Train_Epoch : 14, [32000 / 50000](64%), Train_loss : 0.495252
# Train_Epoch : 14, [38400 / 50000](77%), Train_loss : 0.617215
# Train_Epoch : 14, [44800 / 50000](90%), Train_loss : 0.546273
#
# EPOCH : 14, Test_loss : 0.000090, Test_accuracy : 79.59%
#
# Train_Epoch : 15, [0 / 50000](0%), Train_loss : 0.433183
# Train_Epoch : 15, [6400 / 50000](13%), Train_loss : 0.367834
# Train_Epoch : 15, [12800 / 50000](26%), Train_loss : 0.297977
# Train_Epoch : 15, [19200 / 50000](38%), Train_loss : 0.509598
# Train_Epoch : 15, [25600 / 50000](51%), Train_loss : 0.459634
# Train_Epoch : 15, [32000 / 50000](64%), Train_loss : 0.376177
# Train_Epoch : 15, [38400 / 50000](77%), Train_loss : 0.451572
# Train_Epoch : 15, [44800 / 50000](90%), Train_loss : 0.325453
#
# EPOCH : 15, Test_loss : 0.000085, Test_accuracy : 82.57%
#
# Train_Epoch : 16, [0 / 50000](0%), Train_loss : 0.441740
# Train_Epoch : 16, [6400 / 50000](13%), Train_loss : 0.310956
# Train_Epoch : 16, [12800 / 50000](26%), Train_loss : 0.464598
# Train_Epoch : 16, [19200 / 50000](38%), Train_loss : 0.507267
# Train_Epoch : 16, [25600 / 50000](51%), Train_loss : 0.424716
# Train_Epoch : 16, [32000 / 50000](64%), Train_loss : 0.392435
# Train_Epoch : 16, [38400 / 50000](77%), Train_loss : 0.507103
# Train_Epoch : 16, [44800 / 50000](90%), Train_loss : 0.455428
#
# EPOCH : 16, Test_loss : 0.000047, Test_accuracy : 80.69%
#
# Train_Epoch : 17, [0 / 50000](0%), Train_loss : 0.336572
# Train_Epoch : 17, [6400 / 50000](13%), Train_loss : 0.371322
# Train_Epoch : 17, [12800 / 50000](26%), Train_loss : 0.436977
# Train_Epoch : 17, [19200 / 50000](38%), Train_loss : 0.270940
# Train_Epoch : 17, [25600 / 50000](51%), Train_loss : 0.304580
# Train_Epoch : 17, [32000 / 50000](64%), Train_loss : 0.428494
# Train_Epoch : 17, [38400 / 50000](77%), Train_loss : 0.321805
# Train_Epoch : 17, [44800 / 50000](90%), Train_loss : 0.320866
#
# EPOCH : 17, Test_loss : 0.000064, Test_accuracy : 82.51%
#
# Train_Epoch : 18, [0 / 50000](0%), Train_loss : 0.230770
# Train_Epoch : 18, [6400 / 50000](13%), Train_loss : 0.350761
# Train_Epoch : 18, [12800 / 50000](26%), Train_loss : 0.332670
# Train_Epoch : 18, [19200 / 50000](38%), Train_loss : 0.219597
# Train_Epoch : 18, [25600 / 50000](51%), Train_loss : 0.456973
# Train_Epoch : 18, [32000 / 50000](64%), Train_loss : 0.358675
# Train_Epoch : 18, [38400 / 50000](77%), Train_loss : 0.400735
# Train_Epoch : 18, [44800 / 50000](90%), Train_loss : 0.458976
#
# EPOCH : 18, Test_loss : 0.000084, Test_accuracy : 82.13%
#
# Train_Epoch : 19, [0 / 50000](0%), Train_loss : 0.393829
# Train_Epoch : 19, [6400 / 50000](13%), Train_loss : 0.300750
# Train_Epoch : 19, [12800 / 50000](26%), Train_loss : 0.338684
# Train_Epoch : 19, [19200 / 50000](38%), Train_loss : 0.390624
# Train_Epoch : 19, [25600 / 50000](51%), Train_loss : 0.324427
# Train_Epoch : 19, [32000 / 50000](64%), Train_loss : 0.383210
# Train_Epoch : 19, [38400 / 50000](77%), Train_loss : 0.279732
# Train_Epoch : 19, [44800 / 50000](90%), Train_loss : 0.348102
#
# EPOCH : 19, Test_loss : 0.000056, Test_accuracy : 81.40%
#
# Train_Epoch : 20, [0 / 50000](0%), Train_loss : 0.379685
# Train_Epoch : 20, [6400 / 50000](13%), Train_loss : 0.404354
# Train_Epoch : 20, [12800 / 50000](26%), Train_loss : 0.369543
# Train_Epoch : 20, [19200 / 50000](38%), Train_loss : 0.322492
# Train_Epoch : 20, [25600 / 50000](51%), Train_loss : 0.462661
# Train_Epoch : 20, [32000 / 50000](64%), Train_loss : 0.383196
# Train_Epoch : 20, [38400 / 50000](77%), Train_loss : 0.518084
# Train_Epoch : 20, [44800 / 50000](90%), Train_loss : 0.398264
#
# EPOCH : 20, Test_loss : 0.000058, Test_accuracy : 82.95%
#
# Train_Epoch : 21, [0 / 50000](0%), Train_loss : 0.394592
# Train_Epoch : 21, [6400 / 50000](13%), Train_loss : 0.256660
# Train_Epoch : 21, [12800 / 50000](26%), Train_loss : 0.260731
# Train_Epoch : 21, [19200 / 50000](38%), Train_loss : 0.300258
# Train_Epoch : 21, [25600 / 50000](51%), Train_loss : 0.241764
# Train_Epoch : 21, [32000 / 50000](64%), Train_loss : 0.234385
# Train_Epoch : 21, [38400 / 50000](77%), Train_loss : 0.222654
# Train_Epoch : 21, [44800 / 50000](90%), Train_loss : 0.294919
#
# EPOCH : 21, Test_loss : 0.000081, Test_accuracy : 83.70%
#
# Train_Epoch : 22, [0 / 50000](0%), Train_loss : 0.395225
# Train_Epoch : 22, [6400 / 50000](13%), Train_loss : 0.309127
# Train_Epoch : 22, [12800 / 50000](26%), Train_loss : 0.270268
# Train_Epoch : 22, [19200 / 50000](38%), Train_loss : 0.305037
# Train_Epoch : 22, [25600 / 50000](51%), Train_loss : 0.366074
# Train_Epoch : 22, [32000 / 50000](64%), Train_loss : 0.395889
# Train_Epoch : 22, [38400 / 50000](77%), Train_loss : 0.382694
# Train_Epoch : 22, [44800 / 50000](90%), Train_loss : 0.436869
#
# EPOCH : 22, Test_loss : 0.000053, Test_accuracy : 83.15%
#
# Train_Epoch : 23, [0 / 50000](0%), Train_loss : 0.171303
# Train_Epoch : 23, [6400 / 50000](13%), Train_loss : 0.252905
# Train_Epoch : 23, [12800 / 50000](26%), Train_loss : 0.303428
# Train_Epoch : 23, [19200 / 50000](38%), Train_loss : 0.278217
# Train_Epoch : 23, [25600 / 50000](51%), Train_loss : 0.334050
# Train_Epoch : 23, [32000 / 50000](64%), Train_loss : 0.237633
# Train_Epoch : 23, [38400 / 50000](77%), Train_loss : 0.298524
# Train_Epoch : 23, [44800 / 50000](90%), Train_loss : 0.338297
#
# EPOCH : 23, Test_loss : 0.000072, Test_accuracy : 84.28%
#
# Train_Epoch : 24, [0 / 50000](0%), Train_loss : 0.260054
# Train_Epoch : 24, [6400 / 50000](13%), Train_loss : 0.197879
# Train_Epoch : 24, [12800 / 50000](26%), Train_loss : 0.333285
# Train_Epoch : 24, [19200 / 50000](38%), Train_loss : 0.305410
# Train_Epoch : 24, [25600 / 50000](51%), Train_loss : 0.336930
# Train_Epoch : 24, [32000 / 50000](64%), Train_loss : 0.318860
# Train_Epoch : 24, [38400 / 50000](77%), Train_loss : 0.279214
# Train_Epoch : 24, [44800 / 50000](90%), Train_loss : 0.403046
#
# EPOCH : 24, Test_loss : 0.000068, Test_accuracy : 84.49%
#
# Train_Epoch : 25, [0 / 50000](0%), Train_loss : 0.313573
# Train_Epoch : 25, [6400 / 50000](13%), Train_loss : 0.337836
# Train_Epoch : 25, [12800 / 50000](26%), Train_loss : 0.335873
# Train_Epoch : 25, [19200 / 50000](38%), Train_loss : 0.305415
# Train_Epoch : 25, [25600 / 50000](51%), Train_loss : 0.179322
# Train_Epoch : 25, [32000 / 50000](64%), Train_loss : 0.413731
# Train_Epoch : 25, [38400 / 50000](77%), Train_loss : 0.282725
# Train_Epoch : 25, [44800 / 50000](90%), Train_loss : 0.248098
#
# EPOCH : 25, Test_loss : 0.000049, Test_accuracy : 83.51%
#
# Train_Epoch : 26, [0 / 50000](0%), Train_loss : 0.195157
# Train_Epoch : 26, [6400 / 50000](13%), Train_loss : 0.257570
# Train_Epoch : 26, [12800 / 50000](26%), Train_loss : 0.362030
# Train_Epoch : 26, [19200 / 50000](38%), Train_loss : 0.306780
# Train_Epoch : 26, [25600 / 50000](51%), Train_loss : 0.410892
# Train_Epoch : 26, [32000 / 50000](64%), Train_loss : 0.351417
# Train_Epoch : 26, [38400 / 50000](77%), Train_loss : 0.253305
# Train_Epoch : 26, [44800 / 50000](90%), Train_loss : 0.314382
#
# EPOCH : 26, Test_loss : 0.000087, Test_accuracy : 84.39%
#
# Train_Epoch : 27, [0 / 50000](0%), Train_loss : 0.226242
# Train_Epoch : 27, [6400 / 50000](13%), Train_loss : 0.324055
# Train_Epoch : 27, [12800 / 50000](26%), Train_loss : 0.249126
# Train_Epoch : 27, [19200 / 50000](38%), Train_loss : 0.251417
# Train_Epoch : 27, [25600 / 50000](51%), Train_loss : 0.310428
# Train_Epoch : 27, [32000 / 50000](64%), Train_loss : 0.294913
# Train_Epoch : 27, [38400 / 50000](77%), Train_loss : 0.182597
# Train_Epoch : 27, [44800 / 50000](90%), Train_loss : 0.378400
#
# EPOCH : 27, Test_loss : 0.000101, Test_accuracy : 83.83%
#
# Train_Epoch : 28, [0 / 50000](0%), Train_loss : 0.229913
# Train_Epoch : 28, [6400 / 50000](13%), Train_loss : 0.281565
# Train_Epoch : 28, [12800 / 50000](26%), Train_loss : 0.351083
# Train_Epoch : 28, [19200 / 50000](38%), Train_loss : 0.360943
# Train_Epoch : 28, [25600 / 50000](51%), Train_loss : 0.171844
# Train_Epoch : 28, [32000 / 50000](64%), Train_loss : 0.329990
# Train_Epoch : 28, [38400 / 50000](77%), Train_loss : 0.252392
# Train_Epoch : 28, [44800 / 50000](90%), Train_loss : 0.276358
#
# EPOCH : 28, Test_loss : 0.000074, Test_accuracy : 82.17%
#
# Train_Epoch : 29, [0 / 50000](0%), Train_loss : 0.275543
# Train_Epoch : 29, [6400 / 50000](13%), Train_loss : 0.264613
# Train_Epoch : 29, [12800 / 50000](26%), Train_loss : 0.229089
# Train_Epoch : 29, [19200 / 50000](38%), Train_loss : 0.270409
# Train_Epoch : 29, [25600 / 50000](51%), Train_loss : 0.306636
# Train_Epoch : 29, [32000 / 50000](64%), Train_loss : 0.261567
# Train_Epoch : 29, [38400 / 50000](77%), Train_loss : 0.402627
# Train_Epoch : 29, [44800 / 50000](90%), Train_loss : 0.318052
#
# EPOCH : 29, Test_loss : 0.000033, Test_accuracy : 83.86%
#
# Train_Epoch : 30, [0 / 50000](0%), Train_loss : 0.366018
# Train_Epoch : 30, [6400 / 50000](13%), Train_loss : 0.144675
# Train_Epoch : 30, [12800 / 50000](26%), Train_loss : 0.143338
# Train_Epoch : 30, [19200 / 50000](38%), Train_loss : 0.225244
# Train_Epoch : 30, [25600 / 50000](51%), Train_loss : 0.283438
# Train_Epoch : 30, [32000 / 50000](64%), Train_loss : 0.174940
# Train_Epoch : 30, [38400 / 50000](77%), Train_loss : 0.320382
# Train_Epoch : 30, [44800 / 50000](90%), Train_loss : 0.286133
#
# EPOCH : 30, Test_loss : 0.000022, Test_accuracy : 84.34%
#
# Train_Epoch : 31, [0 / 50000](0%), Train_loss : 0.238420
# Train_Epoch : 31, [6400 / 50000](13%), Train_loss : 0.260708
# Train_Epoch : 31, [12800 / 50000](26%), Train_loss : 0.149290
# Train_Epoch : 31, [19200 / 50000](38%), Train_loss : 0.162127
# Train_Epoch : 31, [25600 / 50000](51%), Train_loss : 0.266546
# Train_Epoch : 31, [32000 / 50000](64%), Train_loss : 0.241737
# Train_Epoch : 31, [38400 / 50000](77%), Train_loss : 0.263209
# Train_Epoch : 31, [44800 / 50000](90%), Train_loss : 0.195042
#
# EPOCH : 31, Test_loss : 0.000072, Test_accuracy : 83.11%
#
# Train_Epoch : 32, [0 / 50000](0%), Train_loss : 0.208775
# Train_Epoch : 32, [6400 / 50000](13%), Train_loss : 0.286535
# Train_Epoch : 32, [12800 / 50000](26%), Train_loss : 0.265283
# Train_Epoch : 32, [19200 / 50000](38%), Train_loss : 0.222567
# Train_Epoch : 32, [25600 / 50000](51%), Train_loss : 0.214936
# Train_Epoch : 32, [32000 / 50000](64%), Train_loss : 0.108923
# Train_Epoch : 32, [38400 / 50000](77%), Train_loss : 0.145777
# Train_Epoch : 32, [44800 / 50000](90%), Train_loss : 0.136076
#
# EPOCH : 32, Test_loss : 0.000089, Test_accuracy : 85.01%
#
# Train_Epoch : 33, [0 / 50000](0%), Train_loss : 0.165572
# Train_Epoch : 33, [6400 / 50000](13%), Train_loss : 0.304501
# Train_Epoch : 33, [12800 / 50000](26%), Train_loss : 0.174811
# Train_Epoch : 33, [19200 / 50000](38%), Train_loss : 0.150960
# Train_Epoch : 33, [25600 / 50000](51%), Train_loss : 0.128038
# Train_Epoch : 33, [32000 / 50000](64%), Train_loss : 0.254667
# Train_Epoch : 33, [38400 / 50000](77%), Train_loss : 0.238390
# Train_Epoch : 33, [44800 / 50000](90%), Train_loss : 0.242334
#
# EPOCH : 33, Test_loss : 0.000061, Test_accuracy : 84.16%
#
# Train_Epoch : 34, [0 / 50000](0%), Train_loss : 0.219679
# Train_Epoch : 34, [6400 / 50000](13%), Train_loss : 0.228026
# Train_Epoch : 34, [12800 / 50000](26%), Train_loss : 0.214323
# Train_Epoch : 34, [19200 / 50000](38%), Train_loss : 0.145344
# Train_Epoch : 34, [25600 / 50000](51%), Train_loss : 0.203535
# Train_Epoch : 34, [32000 / 50000](64%), Train_loss : 0.187244
# Train_Epoch : 34, [38400 / 50000](77%), Train_loss : 0.291930
# Train_Epoch : 34, [44800 / 50000](90%), Train_loss : 0.193680
#
# EPOCH : 34, Test_loss : 0.000079, Test_accuracy : 84.36%
#
# Train_Epoch : 35, [0 / 50000](0%), Train_loss : 0.216009
# Train_Epoch : 35, [6400 / 50000](13%), Train_loss : 0.227024
# Train_Epoch : 35, [12800 / 50000](26%), Train_loss : 0.190706
# Train_Epoch : 35, [19200 / 50000](38%), Train_loss : 0.131025
# Train_Epoch : 35, [25600 / 50000](51%), Train_loss : 0.269621
# Train_Epoch : 35, [32000 / 50000](64%), Train_loss : 0.309112
# Train_Epoch : 35, [38400 / 50000](77%), Train_loss : 0.162554
# Train_Epoch : 35, [44800 / 50000](90%), Train_loss : 0.206622
#
# EPOCH : 35, Test_loss : 0.000082, Test_accuracy : 84.72%
#
# Train_Epoch : 36, [0 / 50000](0%), Train_loss : 0.162385
# Train_Epoch : 36, [6400 / 50000](13%), Train_loss : 0.239165
# Train_Epoch : 36, [12800 / 50000](26%), Train_loss : 0.167619
# Train_Epoch : 36, [19200 / 50000](38%), Train_loss : 0.141856
# Train_Epoch : 36, [25600 / 50000](51%), Train_loss : 0.222112
# Train_Epoch : 36, [32000 / 50000](64%), Train_loss : 0.185214
# Train_Epoch : 36, [38400 / 50000](77%), Train_loss : 0.243384
# Train_Epoch : 36, [44800 / 50000](90%), Train_loss : 0.249236
#
# EPOCH : 36, Test_loss : 0.000065, Test_accuracy : 85.10%
#
# Train_Epoch : 37, [0 / 50000](0%), Train_loss : 0.210178
# Train_Epoch : 37, [6400 / 50000](13%), Train_loss : 0.160544
# Train_Epoch : 37, [12800 / 50000](26%), Train_loss : 0.208990
# Train_Epoch : 37, [19200 / 50000](38%), Train_loss : 0.196197
# Train_Epoch : 37, [25600 / 50000](51%), Train_loss : 0.168766
# Train_Epoch : 37, [32000 / 50000](64%), Train_loss : 0.312822
# Train_Epoch : 37, [38400 / 50000](77%), Train_loss : 0.230525
# Train_Epoch : 37, [44800 / 50000](90%), Train_loss : 0.267583
#
# EPOCH : 37, Test_loss : 0.000085, Test_accuracy : 84.76%
#
# Train_Epoch : 38, [0 / 50000](0%), Train_loss : 0.174088
# Train_Epoch : 38, [6400 / 50000](13%), Train_loss : 0.197889
# Train_Epoch : 38, [12800 / 50000](26%), Train_loss : 0.193326
# Train_Epoch : 38, [19200 / 50000](38%), Train_loss : 0.140694
# Train_Epoch : 38, [25600 / 50000](51%), Train_loss : 0.244338
# Train_Epoch : 38, [32000 / 50000](64%), Train_loss : 0.179734
# Train_Epoch : 38, [38400 / 50000](77%), Train_loss : 0.200708
# Train_Epoch : 38, [44800 / 50000](90%), Train_loss : 0.139938
#
# EPOCH : 38, Test_loss : 0.000084, Test_accuracy : 84.17%
#
# Train_Epoch : 39, [0 / 50000](0%), Train_loss : 0.169882
# Train_Epoch : 39, [6400 / 50000](13%), Train_loss : 0.156580
# Train_Epoch : 39, [12800 / 50000](26%), Train_loss : 0.181638
# Train_Epoch : 39, [19200 / 50000](38%), Train_loss : 0.260475
# Train_Epoch : 39, [25600 / 50000](51%), Train_loss : 0.124726
# Train_Epoch : 39, [32000 / 50000](64%), Train_loss : 0.198653
# Train_Epoch : 39, [38400 / 50000](77%), Train_loss : 0.171386
# Train_Epoch : 39, [44800 / 50000](90%), Train_loss : 0.170349
#
# EPOCH : 39, Test_loss : 0.000060, Test_accuracy : 85.31%
#
# Train_Epoch : 40, [0 / 50000](0%), Train_loss : 0.085431
# Train_Epoch : 40, [6400 / 50000](13%), Train_loss : 0.173887
# Train_Epoch : 40, [12800 / 50000](26%), Train_loss : 0.178019
# Train_Epoch : 40, [19200 / 50000](38%), Train_loss : 0.151867
# Train_Epoch : 40, [25600 / 50000](51%), Train_loss : 0.205649
# Train_Epoch : 40, [32000 / 50000](64%), Train_loss : 0.142022
# Train_Epoch : 40, [38400 / 50000](77%), Train_loss : 0.161766
# Train_Epoch : 40, [44800 / 50000](90%), Train_loss : 0.197140
#
# EPOCH : 40, Test_loss : 0.000130, Test_accuracy : 85.42%
#
# Train_Epoch : 41, [0 / 50000](0%), Train_loss : 0.085320
# Train_Epoch : 41, [6400 / 50000](13%), Train_loss : 0.091043
# Train_Epoch : 41, [12800 / 50000](26%), Train_loss : 0.159637
# Train_Epoch : 41, [19200 / 50000](38%), Train_loss : 0.139197
# Train_Epoch : 41, [25600 / 50000](51%), Train_loss : 0.139009
# Train_Epoch : 41, [32000 / 50000](64%), Train_loss : 0.286256
# Train_Epoch : 41, [38400 / 50000](77%), Train_loss : 0.136228
# Train_Epoch : 41, [44800 / 50000](90%), Train_loss : 0.166355
#
# EPOCH : 41, Test_loss : 0.000080, Test_accuracy : 84.35%
#
# Train_Epoch : 42, [0 / 50000](0%), Train_loss : 0.111315
# Train_Epoch : 42, [6400 / 50000](13%), Train_loss : 0.136881
# Train_Epoch : 42, [12800 / 50000](26%), Train_loss : 0.215550
# Train_Epoch : 42, [19200 / 50000](38%), Train_loss : 0.179674
# Train_Epoch : 42, [25600 / 50000](51%), Train_loss : 0.160793
# Train_Epoch : 42, [32000 / 50000](64%), Train_loss : 0.193934
# Train_Epoch : 42, [38400 / 50000](77%), Train_loss : 0.200789
# Train_Epoch : 42, [44800 / 50000](90%), Train_loss : 0.216981
#
# EPOCH : 42, Test_loss : 0.000054, Test_accuracy : 84.06%
#
# Train_Epoch : 43, [0 / 50000](0%), Train_loss : 0.154589
# Train_Epoch : 43, [6400 / 50000](13%), Train_loss : 0.154009
# Train_Epoch : 43, [12800 / 50000](26%), Train_loss : 0.198276
# Train_Epoch : 43, [19200 / 50000](38%), Train_loss : 0.126526
# Train_Epoch : 43, [25600 / 50000](51%), Train_loss : 0.149179
# Train_Epoch : 43, [32000 / 50000](64%), Train_loss : 0.147027
# Train_Epoch : 43, [38400 / 50000](77%), Train_loss : 0.112481
# Train_Epoch : 43, [44800 / 50000](90%), Train_loss : 0.149938
#
# EPOCH : 43, Test_loss : 0.000038, Test_accuracy : 85.66%
#
# Train_Epoch : 44, [0 / 50000](0%), Train_loss : 0.050555
# Train_Epoch : 44, [6400 / 50000](13%), Train_loss : 0.154444
# Train_Epoch : 44, [12800 / 50000](26%), Train_loss : 0.163497
# Train_Epoch : 44, [19200 / 50000](38%), Train_loss : 0.089109
# Train_Epoch : 44, [25600 / 50000](51%), Train_loss : 0.220406
# Train_Epoch : 44, [32000 / 50000](64%), Train_loss : 0.110177
# Train_Epoch : 44, [38400 / 50000](77%), Train_loss : 0.135944
# Train_Epoch : 44, [44800 / 50000](90%), Train_loss : 0.120601
#
# EPOCH : 44, Test_loss : 0.000022, Test_accuracy : 84.82%
#
# Train_Epoch : 45, [0 / 50000](0%), Train_loss : 0.173070
# Train_Epoch : 45, [6400 / 50000](13%), Train_loss : 0.215953
# Train_Epoch : 45, [12800 / 50000](26%), Train_loss : 0.120198
# Train_Epoch : 45, [19200 / 50000](38%), Train_loss : 0.178426
# Train_Epoch : 45, [25600 / 50000](51%), Train_loss : 0.250241
# Train_Epoch : 45, [32000 / 50000](64%), Train_loss : 0.103271
# Train_Epoch : 45, [38400 / 50000](77%), Train_loss : 0.117934
# Train_Epoch : 45, [44800 / 50000](90%), Train_loss : 0.166202
#
# EPOCH : 45, Test_loss : 0.000045, Test_accuracy : 84.36%
#
# Train_Epoch : 46, [0 / 50000](0%), Train_loss : 0.153994
# Train_Epoch : 46, [6400 / 50000](13%), Train_loss : 0.113834
# Train_Epoch : 46, [12800 / 50000](26%), Train_loss : 0.176665
# Train_Epoch : 46, [19200 / 50000](38%), Train_loss : 0.223737
# Train_Epoch : 46, [25600 / 50000](51%), Train_loss : 0.098053
# Train_Epoch : 46, [32000 / 50000](64%), Train_loss : 0.126162
# Train_Epoch : 46, [38400 / 50000](77%), Train_loss : 0.209095
# Train_Epoch : 46, [44800 / 50000](90%), Train_loss : 0.082342
#
# EPOCH : 46, Test_loss : 0.000084, Test_accuracy : 85.09%
#
# Train_Epoch : 47, [0 / 50000](0%), Train_loss : 0.108294
# Train_Epoch : 47, [6400 / 50000](13%), Train_loss : 0.142173
# Train_Epoch : 47, [12800 / 50000](26%), Train_loss : 0.067456
# Train_Epoch : 47, [19200 / 50000](38%), Train_loss : 0.181549
# Train_Epoch : 47, [25600 / 50000](51%), Train_loss : 0.174466
# Train_Epoch : 47, [32000 / 50000](64%), Train_loss : 0.098545
# Train_Epoch : 47, [38400 / 50000](77%), Train_loss : 0.133827
# Train_Epoch : 47, [44800 / 50000](90%), Train_loss : 0.109574
#
# EPOCH : 47, Test_loss : 0.000081, Test_accuracy : 84.55%
#
# Train_Epoch : 48, [0 / 50000](0%), Train_loss : 0.134010
# Train_Epoch : 48, [6400 / 50000](13%), Train_loss : 0.151925
# Train_Epoch : 48, [12800 / 50000](26%), Train_loss : 0.187201
# Train_Epoch : 48, [19200 / 50000](38%), Train_loss : 0.164208
# Train_Epoch : 48, [25600 / 50000](51%), Train_loss : 0.106464
# Train_Epoch : 48, [32000 / 50000](64%), Train_loss : 0.125268
# Train_Epoch : 48, [38400 / 50000](77%), Train_loss : 0.040309
# Train_Epoch : 48, [44800 / 50000](90%), Train_loss : 0.165598
#
# EPOCH : 48, Test_loss : 0.000108, Test_accuracy : 85.03%
#
# Train_Epoch : 49, [0 / 50000](0%), Train_loss : 0.185860
# Train_Epoch : 49, [6400 / 50000](13%), Train_loss : 0.115152
# Train_Epoch : 49, [12800 / 50000](26%), Train_loss : 0.132605
# Train_Epoch : 49, [19200 / 50000](38%), Train_loss : 0.162665
# Train_Epoch : 49, [25600 / 50000](51%), Train_loss : 0.060873
# Train_Epoch : 49, [32000 / 50000](64%), Train_loss : 0.177572
# Train_Epoch : 49, [38400 / 50000](77%), Train_loss : 0.252753
# Train_Epoch : 49, [44800 / 50000](90%), Train_loss : 0.121969
#
# EPOCH : 49, Test_loss : 0.000141, Test_accuracy : 85.22%
#
# Train_Epoch : 50, [0 / 50000](0%), Train_loss : 0.122961
# Train_Epoch : 50, [6400 / 50000](13%), Train_loss : 0.102367
# Train_Epoch : 50, [12800 / 50000](26%), Train_loss : 0.131265
# Train_Epoch : 50, [19200 / 50000](38%), Train_loss : 0.146299
# Train_Epoch : 50, [25600 / 50000](51%), Train_loss : 0.210823
# Train_Epoch : 50, [32000 / 50000](64%), Train_loss : 0.149894
# Train_Epoch : 50, [38400 / 50000](77%), Train_loss : 0.113753
# Train_Epoch : 50, [44800 / 50000](90%), Train_loss : 0.140154
#
# EPOCH : 50, Test_loss : 0.000045, Test_accuracy : 84.84%
#
# Train_Epoch : 51, [0 / 50000](0%), Train_loss : 0.087395
# Train_Epoch : 51, [6400 / 50000](13%), Train_loss : 0.099650
# Train_Epoch : 51, [12800 / 50000](26%), Train_loss : 0.106218
# Train_Epoch : 51, [19200 / 50000](38%), Train_loss : 0.114712
# Train_Epoch : 51, [25600 / 50000](51%), Train_loss : 0.061600
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 5
#       2 best_accuracy = 0
#       4 for Epoch in range(1, EPOCHS + 1) :
# ----> 5     train(model, train_loader, optimizer)
#       6     test_loss, test_accuracy = evaluate(model, test_loader)
#       7     print('\nEPOCH : {}, Test_loss : {:.6f}, Test_accuracy : {:.2f}%\n'.format(
#       8         Epoch, test_loss, test_accuracy
#       9     ))
#
# Cell In[57], line 11, in train(model, train_loader, optimizer, log_intervals)
#       9 loss = criterion(output, label)
#      10 loss.backward()
# ---> 11 optimizer.step()
#      13 if batch_idx % log_intervals == 0 :
#      14     print('Train_Epoch : {}, [{} / {}]({:.0f}%), Train_loss : {:.6f}'.format(
#      15         Epoch, batch_idx * len(image), len(train_loader.dataset),
#      16         batch_idx * 100 / len(train_loader), loss.item()
#      17     ))
#
# File c:\Users\Admin\anaconda3\envs\pytorch_only\lib\site-packages\torch\optim\optimizer.py:113, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     111 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     112 with torch.autograd.profiler.record_function(profile_name):
# --> 113     return func(*args, **kwargs)
#
# File c:\Users\Admin\anaconda3\envs\pytorch_only\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File c:\Users\Admin\anaconda3\envs\pytorch_only\lib\site-packages\torch\optim\adam.py:157, in Adam.step(self, closure)
#     153                 max_exp_avg_sqs.append(state['max_exp_avg_sq'])
#     155             state_steps.append(state['step'])
# --> 157     adam(params_with_grad,
#     158          grads,
#     159          exp_avgs,
#     160          exp_avg_sqs,
#     161          max_exp_avg_sqs,
#     162          state_steps,
#     163          amsgrad=group['amsgrad'],
#     164          beta1=beta1,
#     165          beta2=beta2,
#     166          lr=group['lr'],
#     167          weight_decay=group['weight_decay'],
#     168          eps=group['eps'],
#     169          maximize=group['maximize'],
#     170          foreach=group['foreach'],
#     171          capturable=group['capturable'])
#     173 return loss
#
# File c:\Users\Admin\anaconda3\envs\pytorch_only\lib\site-packages\torch\optim\adam.py:213, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     210 else:
#     211     func = _single_tensor_adam
# --> 213 func(params,
#     214      grads,
#     215      exp_avgs,
#     216      exp_avg_sqs,
#     217      max_exp_avg_sqs,
#     218      state_steps,
#     219      amsgrad=amsgrad,
#     220      beta1=beta1,
#     221      beta2=beta2,
#     222      lr=lr,
#     223      weight_decay=weight_decay,
#     224      eps=eps,
#     225      maximize=maximize,
#     226      capturable=capturable)
#
# File c:\Users\Admin\anaconda3\envs\pytorch_only\lib\site-packages\torch\optim\adam.py:305, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable)
#     303     denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     304 else:
# --> 305     denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     307 param.addcdiv_(exp_avg, denom, value=-step_size)
#
# KeyboardInterrupt:
