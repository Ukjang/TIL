# %%
triangle = [[7], [3, 8], [8, 1, 0], [2, 7, 4, 4], [4, 5, 2, 6, 5]]
result=30

# %%
# 본인 idx + 0 or 1로만 이동 가능
# 이전값 존재여부 확인하고 불러오기?
ans_list = {}
row=1
idx ='0'
for _ in range(2**(len(triangle - 1))) :
    
    while row < len(triangle):
        if ans_list[idx] :
            pass
        else :
            ans_list[idx] 
        triangle[row][0]

# %%
ans_list = {}
temp = ''
ans_list[temp] = 0
for row in range(len(triangle)) :
    for nm in range(len(triangle[row])) :
        temp1 = temp + str(nm)
        ans_list[temp1] = ans_list[temp] + triangle[row][nm]
        temp += str(nm)
        print(row,nm, ans_list)
# Out:
# 0 0 {'': 0, '0': 7}
# 1 0 {'': 0, '0': 7, '00': 10}
# 1 1 {'': 0, '0': 7, '00': 10, '001': 18}
# 2 0 {'': 0, '0': 7, '00': 10, '001': 18, '0010': 26}
# 2 1 {'': 0, '0': 7, '00': 10, '001': 18, '0010': 26, '00101': 27}
# 2 2 {'': 0, '0': 7, '00': 10, '001': 18, '0010': 26, '00101': 27, '001012': 27}
# 3 0 {'': 0, '0': 7, '00': 10, '001': 18, '0010': 26, '00101': 27, '001012': 27, '0010120': 29}
# 3 1 {'': 0, '0': 7, '00': 10, '001': 18, '0010': 26, '00101': 27, '001012': 27, '0010120': 29, '00101201': 36}
# 3 2 {'': 0, '0': 7, '00': 10, '001': 18, '0010': 26, '00101': 27, '001012': 27, '0010120': 29, '00101201': 36, '001012012': 40}
# 3 3 {'': 0, '0': 7, '00': 10, '001': 18, '0010': 26, '00101': 27, '001012': 27, '0010120': 29, '00101201': 36, '001012012': 40, '0010120123': 44}
# 4 0 {'': 0, '0': 7, '00': 10, '001': 18, '0010': 26, '00101': 27, '001012': 27, '0010120': 29, '00101201': 36, '001012012': 40, '0010120123': 44, '00101201230': 48}
# ...

# %%
ans_list.keys()
# Out:
# dict_keys(['0', '00', '001', '0010', '00101', '001012', '0010120', '00101201', '001012012', '0010120123', '00101201230', '001012012301', '0010120123012', '00101201230123', '001012012301234'])

# %%
triangle[1]
# Out:
# [3, 8]

# %%
01111
01110
01101
01100
01011
01010
01001
01000
00111
00110
00101
00100
00011
00010
00001
00000
